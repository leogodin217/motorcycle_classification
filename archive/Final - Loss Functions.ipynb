# %%
# Python setup
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import torch.nn as nn
#import data functions and constants (no caps for easier typing)
import modelingfunctions.dataprocessing as d
import modelingfunctions.modeling as m
import modelingfunctions.utilities as u

# %%
num_targets = 5
batch_size = 64
epochs=10

# %% [markdown]
# ## Cross Entropy Loss

# %%
dataloaders = d.get_target_dataloader(d.complex_data, num_targets=num_targets,
                                      batch_size=batch_size, pin_memory=True,
                                      num_workers=2)
model = m.get_model(num_targets, generalization='batchnorm', layers='34')
optimizer = m.get_adam_optimizer(model)
criterion = nn.CrossEntropyLoss()

results = m.train_model(dataloaders=dataloaders, model=model, criterion=criterion,  topk=3,
                        name="Cross Entropy LOSS", optimizer=optimizer, epochs=epochs, 
                        clear_cuda_cache=True, print_epoch=True)
print(results['run_time'])
u.plot_results(results)
u.plot_accuracy(results)
# Out:
# Using batch normalization for generalization
# Gathering configurations
# Configuration: 0:00:07.164199
# Epoch: 1
# Train_loss: 1.8348978757858276, Val loss: 1.5789874792099, Test Accuracy: 0.3
# Epoch: 2
# Train_loss: 1.56737220287323, Val loss: 1.5581355094909668, Test Accuracy: 0.4
# Epoch: 3
# Train_loss: 1.5054579973220825, Val loss: 1.5408499240875244, Test Accuracy: 0.4
# Epoch: 4
# Train_loss: 1.4811172485351562, Val loss: 1.5255025625228882, Test Accuracy: 0.5
# Epoch: 5
# Train_loss: 1.4416536092758179, Val loss: 1.5076940059661865, Test Accuracy: 0.5
# Epoch: 6
# Train_loss: 1.3891026973724365, Val loss: 1.4879775047302246, Test Accuracy: 0.5
# Epoch: 7
# Train_loss: 1.37860107421875, Val loss: 1.4672223329544067, Test Accuracy: 0.5
# Epoch: 8
# Train_loss: 1.3285545110702515, Val loss: 1.443387746810913, Test Accuracy: 0.5
# Epoch: 9
# Train_loss: 1.2931160926818848, Val loss: 1.418373703956604, Test Accuracy: 0.6
# Epoch: 10
# Train_loss: 1.2658369541168213, Val loss: 1.3956180810928345, Test Accuracy: 0.6
# 0:01:21.716071

# %% [markdown]
# ## NLL Loss

# %%
dataloaders = d.get_target_dataloader(d.complex_data, num_targets=num_targets,
                                      batch_size=batch_size)
model = m.get_model(num_targets, generalization='batchnorm', layers='34')
optimizer = m.get_adam_optimizer(model)
criterion = nn.NLLLoss()

results = m.train_model(dataloaders=dataloaders, model=model, criterion=criterion,  topk=3,
                        name="NLL LOSS", optimizer=optimizer, epochs=epochs, 
                        clear_cuda_cache=True, print_epoch=True)
print(results['run_time'])
u.plot_results(results)
u.plot_accuracy(results)
# Out:
# Using batch normalization for generalization
# Gathering configurations
# Configuration: 0:00:02.348102
# Epoch: 1
# Train_loss: 1.647417426109314, Val loss: 1.5749738216400146, Test Accuracy: 0.3
# Epoch: 2
# Train_loss: 1.5678870677947998, Val loss: 1.561238169670105, Test Accuracy: 0.2
# Epoch: 3
# Train_loss: 1.5358850955963135, Val loss: 1.5518916845321655, Test Accuracy: 0.2
# Epoch: 4
# Train_loss: 1.5065077543258667, Val loss: 1.5437967777252197, Test Accuracy: 0.2
# Epoch: 5
# Train_loss: 1.4876093864440918, Val loss: 1.5296704769134521, Test Accuracy: 0.2
# Epoch: 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-473749737c23> in <module>
#       7 results = m.train_model(dataloaders=dataloaders, model=model, criterion=criterion,  topk=3,
#       8                         name="NLL LOSS", optimizer=optimizer, epochs=epochs,
# ----> 9                         clear_cuda_cache=True, print_epoch=True)
#      10 print(results['run_time'])
#      11 u.plot_results(results)
#
# c:\users\leogo\onedrive\regis\msds\practicum_2\project\code\modelingfunctions\modelingfunctions\modeling.py in train_model(dataloaders, model, criterion, optimizer, epochs, topk, clear_cuda_cache, name, print_epoch)
#     220         validation_results = forward_pass(model, dataloaders['val'], criterion,
#     221                                           num_images=num_val_images,
# --> 222                                           clear_cuda_cache=clear_cuda_cache)
#     223         # Get test accuracy
#     224         test_accuracy = get_accuracy(model, dataloaders['test'],
#
# c:\users\leogo\onedrive\regis\msds\practicum_2\project\code\modelingfunctions\modelingfunctions\modeling.py in forward_pass(model, dataloader, criterion, num_images, clear_cuda_cache)
#      84
#      85         for data, target in dataloader:
# ---> 86             data = data.to('cuda')
#      87             target = target.to('cuda')
#      88             result = model(data)
#
# KeyboardInterrupt:
